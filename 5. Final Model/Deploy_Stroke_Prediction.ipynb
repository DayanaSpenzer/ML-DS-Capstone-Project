# %%
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
loaded_file=pickle.load((open("Final_Stroke_Prediction.sav","rb")))
result=loaded_file.predict([[88,1,0,0,100.4,25.4,1,0,1,0,0,1,0,0,1]])
result
# Out:
# array([0])
