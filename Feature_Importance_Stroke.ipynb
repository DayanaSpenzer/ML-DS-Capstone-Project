# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
def split_scalar(in_x,out_y):
    x_train,x_test,y_train,y_test=train_test_split(in_x,out_y,test_size=0.25,random_state=0)
    sc=StandardScaler()
    x_train=sc.fit_transform(x_train)
    x_test=sc.transform(x_test)
    return x_train,x_test,y_train,y_test

# %%
def decision(x_train,y_train,x_test):
    from sklearn.tree import DecisionTreeClassifier
    classifier=DecisionTreeClassifier()
    classifier.fit(x_train,y_train)
    importance=classifier.feature_importances_
    #for i, v in enumerate(importance):
      #  print(f'Feature: {i}, Score: {v:.5f}')
      #  plt.bar([x for x in range(len(importance))], importance)
      #  plt.show()
    return classifier,importance

# %%
def ranforest(x_train,y_train,x_test):
    from sklearn.ensemble import RandomForestClassifier
    classifier=RandomForestClassifier()
    classifier.fit(x_train,y_train)
    importance=classifier.feature_importances_
    #for i, v in enumerate(importance):
      #  print(f'Feature: {i}, Score: {v:.5f}')
      #  plt.bar([x for x in range(len(importance))], importance)
      #  plt.show()
    return classifier,importance

# %%
def ranforest_permutation(x_train,y_train,x_test):
    from sklearn.inspection import permutation_importance
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.datasets import make_classification
    from sklearn.model_selection import train_test_split
    classifier = RandomForestClassifier()
    classifier.fit(x_train, y_train)

# Perform permutation importance
    results = permutation_importance(classifier, x_test, y_test, scoring='accuracy')
    importance=results.importances_mean

    return classifier, importance

# %%
def Feature_Imp_Classification(classifier,importance):
    #dataframe=pd.DataFrame(index=['Importance Score'],columns=['Logistic','SVM1','SVMnl','KNN','Navie','Decision','Random'])
    dataframe=pd.DataFrame(index=['Importance Score'],columns=['Decision','Random Forest','RanForest Permutation'])
    for number,idex in enumerate(dataframe.index):
        #dataframe['Logistic'][idex]=acclog[number]
        #dataframe['SVM1'][idex]=accsvml[number]
        #dataframe['SVMnl'][idex]=accsvmnl[number]
        #dataframe['KNN'][idex]=accknn[number]
        #dataframe['Navie'][idex]=accnav[number]
        dataframe['Decision'][idex]=scoredes[number].max()
        dataframe['Random Forest'][idex]=scorerf[number].max()
        dataframe['RanForest Permutation'][idex]=scorerfp[number].max()
    return dataframe

# %%
dataset1=pd.read_csv("Stroke_Prepdata.csv",index_col=None)

df2=dataset1
df2=pd.get_dummies(df2,drop_first=True)

in_x=df2.drop('stroke', axis=1)
out_y=df2['stroke']

# %%
x_train,x_test,y_train,y_test=split_scalar(in_x,out_y)
scoredes=[]
scorerf=[]
scorerfp=[]
classifier,importance=decision(x_train,y_train,x_test)
scoredes.append(importance)
classifier,importance=ranforest(x_train,y_train,x_test)
scorerf.append(importance)
classifier,importance=ranforest(x_train,y_train,x_test)
scorerfp.append(importance)
result=Feature_Imp_Classification(classifier,importance)
result
# Out:
#                   Decision Random Forest RanForest Permutation
# Importance Score  0.267672      0.204826              0.208868
